# %%
import pandas as pd

### 讀入series
df = pd.read_csv('price2884.csv', index_col='date', parse_dates=['date'])
price = df.squeeze()


price.head()
# Out:
# date
# 2018-01-02    18.90
# 2018-01-03    19.35
# 2018-01-04    19.30
# 2018-01-05    19.35
# 2018-01-08    19.60
# Name: price, dtype: float64

# %%
from stocker import Stocker


esun = Stocker(price)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# the stock Stocker Initialized. Data covers 2018-01-02 00:00:00 to 2019-05-28 00:00:00.
# C:\Users\abath\Desktop\Stocker-master\stocker.py:46: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\abath\Anaconda3\lib\site-packages\pandas\core\indexing.py:961: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\abath\Desktop\Stocker-master\stocker.py:49: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# ...

# %%
model, model_data = esun.create_prophet_model(days=10)
# Out:
# C:\Users\abath\Desktop\Stocker-master\stocker.py:436: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
# Predicted Price on 2019-06-07 00:00:00 = $26.63

# %%
import pandas as pd

### 讀入series
df = pd.read_csv('price2330.csv', index_col='date', parse_dates=['date'])
price = df.squeeze()


price.head()
# Out:
# date
# 2009-11-23    62.000000
# 2009-11-24    62.400002
# 2009-11-25    62.700001
# 2009-11-26    62.000000
# 2009-11-27    60.000000
# Name: price, dtype: float64

# %%
from stocker import Stocker


esun = Stocker(price)
# Out:
# the stock Stocker Initialized. Data covers 2009-11-23 00:00:00 to 2019-11-22 00:00:00.
# C:\Users\abath\Desktop\Stocker-master\stocker.py:46: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\abath\Anaconda3\lib\site-packages\pandas\core\indexing.py:961: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\abath\Desktop\Stocker-master\stocker.py:49: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# ...

# %%
model, model_data = esun.create_prophet_model(days=10)
# Out:
# Predicted Price on 2019-12-02 00:00:00 = $301.21
# C:\Users\abath\Desktop\Stocker-master\stocker.py:436: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated

# %%
esun.evaluate_prediction(start_date='2019-09-01', end_date='2019-11-22')
# Out:
# C:\Users\abath\Anaconda3\lib\site-packages\pandas\core\series.py:856: RuntimeWarning:
#
# invalid value encountered in sign
#
# C:\Users\abath\Desktop\Stocker-master\stocker.py:517: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\abath\Desktop\Stocker-master\stocker.py:518: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\abath\Desktop\Stocker-master\stocker.py:529: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# ...

# %%
esun.changepoint_prior_analysis(changepoint_priors=[0.001, 0.05, 0.1, 0.2])

# %%
esun.changepoint_prior_scale = 0.001
esun.evaluate_prediction(start_date='2019-09-01', end_date='2019-11-22')
# Out:
# C:\Users\abath\Anaconda3\lib\site-packages\pandas\core\series.py:856: RuntimeWarning:
#
# invalid value encountered in sign
#
# C:\Users\abath\Desktop\Stocker-master\stocker.py:517: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\abath\Desktop\Stocker-master\stocker.py:518: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\abath\Desktop\Stocker-master\stocker.py:529: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# ...

# %%
esun.changepoint_prior_validation(start_date='2018-09-01', end_date='2019-11-22', changepoint_priors=[0.001, 0.05, 0.1,0.15, 0.2, 0.25,0.4, 0.5, 0.6])
# Out:
# Validation Range 2018-09-03 00:00:00 to 2019-11-22 00:00:00.
# C:\Users\abath\Desktop\Stocker-master\stocker.py:906: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\abath\Desktop\Stocker-master\stocker.py:923: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\abath\Desktop\Stocker-master\stocker.py:924: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# ...

# %%
esun.evaluate_prediction(nshares=1000)
# Out:
# You played the stock market in the stock from 2018-11-22 00:00:00 to 2019-11-22 00:00:00 with 1000 shares.
#
# When the model predicted an increase, the price increased 48.23% of the time.
# When the model predicted a  decrease, the price decreased  40.82% of the time.
#
# The total profit using the Prophet model = $24000.00.
# The Buy and Hold strategy profit =         $92000.00.
#
# Thanks for playing the stock market!
# C:\Users\abath\Anaconda3\lib\site-packages\pandas\core\series.py:856: RuntimeWarning:
#
# invalid value encountered in sign
#
# C:\Users\abath\Desktop\Stocker-master\stocker.py:517: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\abath\Desktop\Stocker-master\stocker.py:518: FutureWarning:
#
#
# .ix is deprecated. Please use
# ...

# %%
esun.predict_future(days=10)

esun.predict_future(days=100)
# Out:
# Predicted Increase:
#
# Empty DataFrame
# Columns: [Date, estimate, change, upper, lower]
# Index: []
#
# Predicted Decrease:
#
#          Date    estimate    change       upper       lower
# 2  2019-11-24  270.877204 -4.382624  285.126775  256.056115
# 3  2019-11-25  268.728933 -2.148271  283.318915  252.468859
# 4  2019-11-26  266.790726 -1.938207  283.492107  251.010049
# 5  2019-11-27  265.298397 -1.492329  281.168544  249.863023
# 6  2019-11-28  264.460100 -0.838297  279.886129  248.658847
# 7  2019-11-29  264.187456 -0.272644  280.239836  249.743323
# 9  2019-12-01  263.370346 -0.817110  277.900445  247.920765
# 10 2019-12-02  262.096646 -1.273700  276.994985  247.113473
# Predicted Increase:
#
#           Date    estimate    change       upper       lower
# 13  2019-12-05  259.704620  0.011003  275.227159  244.116986
# 14  2019-12-06  260.338661  0.634040  274.719542  244.778105
# 16  2019-12-08  260.366289  0.027628  275.507374  245.450782
# ...
