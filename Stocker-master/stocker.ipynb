# %%
from stocker import Stocker

# %%
import pandas as pd

### 讀入series
df = pd.read_csv('price2884.csv', index_col='date', parse_dates=['date'])
price = df.squeeze()

price.head(10)
# Out:
# date
# 2018-01-02    18.90
# 2018-01-03    19.35
# 2018-01-04    19.30
# 2018-01-05    19.35
# 2018-01-08    19.60
# 2018-01-09    19.60
# 2018-01-10    19.60
# 2018-01-11    19.55
# 2018-01-12    19.50
# 2018-01-15    19.50
# Name: price, dtype: float64

# %%
from stocker import Stocker

esun = Stocker(price)
# Out:
# the stock Stocker Initialized. Data covers 2018-01-02 00:00:00 to 2019-05-28 00:00:00.

# %%
model, model_data = esun.create_prophet_model(days=10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Predicted Price on 2019-06-07 00:00:00 = $26.62
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
esun.evaluate_prediction(start_date='2019-02-04', end_date='2019-05-28')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\Users\hn280\Downloads\Stocker-master\Stocker-master\stocker.py:500: RuntimeWarning: invalid value encountered in sign
#   test['correct'] = (np.sign(test['pred_diff']) == np.sign(test['real_diff'])) * 1
# Prediction Range: 2019-02-04 00:00:00 to 2019-05-28 00:00:00.
#
# Predicted price on 2020-01-30 00:00:00 = $27.17.
# Actual price on    2019-05-28 00:00:00 = $26.65.
#
# Average Absolute Error on Training Data = $0.15.
# Average Absolute Error on Testing  Data = $0.58.
#
# When the model predicted an increase, the price increased 54.41% of the time.
# When the model predicted a  decrease, the price decreased  33.33% of the time.
#
# The actual value was within the 80% confidence interval 27.78% of the time.

# %%
esun.changepoint_prior_analysis(changepoint_priors=[0.001, 0.05, 0.1, 0.2])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
esun.changepoint_prior_validation(start_date='2018-01-04', end_date='2019-01-03', changepoint_priors=[0.001, 0.05, 0.1,0.15, 0.2, 0.25,0.4, 0.5, 0.6])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:n_changepoints greater than number of observations.Using 0.0.
# Validation Range 2018-01-04 00:00:00 to 2019-01-03 00:00:00.
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:n_changepoints greater than number of observations.Using 0.0.
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:n_changepoints greater than number of observations.Using 0.0.
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:n_changepoints greater than number of observations.Using 0.0.
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:n_changepoints greater than number of observations.Using 0.0.
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:n_changepoints greater than number of observations.Using 0.0.
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:n_changepoints greater than number of observations.Using 0.0.
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:n_changepoints greater than number of observations.Using 0.0.
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:n_changepoints greater than number of observations.Using 0.0.
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
#      cps     train_err   train_range     test_err  test_range
# 0  0.001  5.009326e-13  1.267309e-07  4441.255378    0.001190
# 1  0.050  1.963230e-11  2.425221e-08  1795.028242    0.001145
# 2  0.100  3.069545e-12  4.370818e-09   837.806309    0.001152
# 3  0.150  5.346834e-13  1.786720e-08  3017.192321    0.001149
# 4  0.200  3.730349e-14  4.016300e-09  2381.124025    0.001157
# 5  0.250  4.263256e-14  2.426858e-08  1243.842808    0.001166
# 6  0.400  1.776357e-14  2.103679e-09  5512.673391    0.001132
# 7  0.500  7.105427e-15  6.738254e-10  8080.450549    0.001113
# 8  0.600  1.776357e-14  1.641679e-09  3266.924649    0.001204

# %%
esun.changepoint_prior_scale = 0.1

# %%
esun.evaluate_prediction(start_date='2019-02-04', end_date='2019-05-28')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\Users\hn280\Downloads\Stocker-master\Stocker-master\stocker.py:500: RuntimeWarning: invalid value encountered in sign
#   test['correct'] = (np.sign(test['pred_diff']) == np.sign(test['real_diff'])) * 1
# Prediction Range: 2019-02-04 00:00:00 to 2019-05-28 00:00:00.
#
# Predicted price on 2020-01-30 00:00:00 = $30.34.
# Actual price on    2019-05-28 00:00:00 = $26.65.
#
# Average Absolute Error on Training Data = $0.15.
# Average Absolute Error on Testing  Data = $0.40.
#
# When the model predicted an increase, the price increased 55.71% of the time.
# When the model predicted a  decrease, the price decreased  100.00% of the time.
#
# The actual value was within the 80% confidence interval 44.44% of the time.

# %%
esun.evaluate_prediction(nshares=1000)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\Users\hn280\Downloads\Stocker-master\Stocker-master\stocker.py:500: RuntimeWarning: invalid value encountered in sign
#   test['correct'] = (np.sign(test['pred_diff']) == np.sign(test['real_diff'])) * 1
# C:\Users\hn280\Downloads\Stocker-master\Stocker-master\stocker.py:591: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_pred_increase['pred_profit'] = prediction_profit
# You played the stock market in the stock from 2018-05-28 00:00:00 to 2019-05-28 00:00:00 with 1000 shares.
#
# When the model predicted an increase, the price increased 50.00% of the time.
# When the model predicted a  decrease, the price decreased  42.74% of the time.
#
# The total profit using the Prophet model = $6150.00.
# The Buy and Hold strategy profit =         $4850.00.
#
# Thanks for playing the stock market!

# %%
esun.predict_future(days=10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Predicted Increase:
#
#          Date   estimate    change      upper      lower
# 1  2019-05-29  26.092074  0.050050  26.379089  25.794437
# 2  2019-05-30  26.162807  0.070733  26.439314  25.879959
# 3  2019-05-31  26.249493  0.086686  26.522312  25.966286
# 5  2019-06-02  26.390151  0.140658  26.684910  26.101624
# 6  2019-06-03  26.422733  0.032582  26.713371  26.134707
# 7  2019-06-04  26.446747  0.024014  26.732730  26.177052
# 8  2019-06-05  26.482903  0.036156  26.778605  26.213267
# 9  2019-06-06  26.537050  0.054147  26.824472  26.232066
# 10 2019-06-07  26.595836  0.058786  26.874750  26.294006
#
# Predicted Decrease:
#
# Empty DataFrame
# Columns: [Date, estimate, change, upper, lower]
# Index: []

# %%
esun.predict_future(days=100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\fbprophet\forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
#